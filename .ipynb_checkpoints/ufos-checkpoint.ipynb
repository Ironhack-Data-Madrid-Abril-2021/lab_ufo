# %% [markdown]
# # UFO Question
#
# Our data science team has predicted that the Earth is going to be invaded by an alien force in the
# next years. Our only hope is to replicate a device that can block all alien technology in a radius of
# ~300km. Sadly, the device was sold in 2004 to an anonymous buyer to protect her hometown and
# we don't know how contact her again. We know that the device has been active since 2004 in one
# city in the USA, and we want to know where to start our search.
# We've included a dataset called ​ufo.csv​. This dataset contains over 80,000 reports of UFO sightings
# over the last century (all of them verified by the ESA). Using this dataset, try to guess the city in
# which the device has been hidden.

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: requests in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: numpy in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from folium) (1.20.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install keplergl
# Out:
# Collecting keplergl
#   Downloading keplergl-0.2.2.tar.gz (7.9 MB)
# Requirement already satisfied: ipywidgets<8,>=7.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from keplergl) (7.6.3)
# Collecting traittypes>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting geopandas>=0.5.0
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from keplergl) (1.2.4)
# Collecting Shapely>=1.6.4.post2
#   Downloading Shapely-1.7.1-cp39-cp39-win_amd64.whl (978 kB)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.1.0-cp39-cp39-win_amd64.whl (14.5 MB)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.19.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.18.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.17.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.16.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.15.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.14.tar.gz (1.3 MB)
#   Downloading Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.13.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.12.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.11.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.10.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.9.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.8.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.7.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.6.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.5.tar.gz (1.7 MB)
#   Downloading Fiona-1.8.4.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.3.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.2.tar.gz (1.2 MB)
#   Downloading Fiona-1.8.1.tar.gz (1.1 MB)
#   Downloading Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas>=0.5.0
#   Downloading geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Downloading Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (7.21.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (3.5.1)
# Requirement already satisfied: jupyter-client in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.17)
# Requirement already satisfied: pickleshare in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: colorama in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.4)
# Requirement already satisfied: decorator in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (4.4.2)
# Requirement already satisfied: pygments in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.8.1)
# Requirement already satisfied: backcall in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (49.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (4.7.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (0.17.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->keplergl) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->keplergl) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->keplergl) (2021.1)
# Requirement already satisfied: wcwidth in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.5)
# Requirement already satisfied: certifi in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from pyproj>=2.2.0->geopandas>=0.5.0->keplergl) (2020.12.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (6.2.0)
# Requirement already satisfied: jinja2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.9.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.9.3)
# Requirement already satisfied: argon2-cffi in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (22.0.3)
# Requirement already satisfied: nbconvert in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (6.0.7)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7.0.0->keplergl) (300)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.20)
# Collecting cligj>=0.4
#   Downloading cligj-0.7.1-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click<8,>=4.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.1.1)
# Requirement already satisfied: testpath in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.4)
# Requirement already satisfied: bleach in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (3.3.0)
# Requirement already satisfied: defusedxml in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.4)
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_ae93753bf94243fbb57aad30bd09d3ae\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_ae93753bf94243fbb57aad30bd09d3ae\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-eoyexaow'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_ae93753bf94243fbb57aad30bd09d3ae\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_970f31dc9f4740e6a6ccc89ee6f64c0b\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_970f31dc9f4740e6a6ccc89ee6f64c0b\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-uwxoas5t'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_970f31dc9f4740e6a6ccc89ee6f64c0b\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_16a6a30c682e4fb4934f17a93d4b61f0\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_16a6a30c682e4fb4934f17a93d4b61f0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-bgsddqaq'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_16a6a30c682e4fb4934f17a93d4b61f0\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_f8d97f2e653a4d6cb5e36ff0e5fe0771\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_f8d97f2e653a4d6cb5e36ff0e5fe0771\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-binhe9hv'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_f8d97f2e653a4d6cb5e36ff0e5fe0771\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages

#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/d8/feab39987296437fbdc3029fb39752a14355d217d73b93471010b8dd63a3/Fiona-1.8.12.tar.gz#sha256=c9266ddf6ae2a64fcea20014ddf27f800ac07584f2fdb09c2a02f3b3a52e371c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_0182f46e4d8a4891af359ed9b1056de1\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_0182f46e4d8a4891af359ed9b1056de1\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-fxv7homr'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_0182f46e4d8a4891af359ed9b1056de1\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9d/f4/0a0ddc6174c4a93679b5f1dd3535e7ef8989828e6d5f86112de681f8c87b/Fiona-1.8.11.tar.gz#sha256=1e7ca9e051f5bffa1c43c70d573da9ca223fc076b84fa73380614fc02b9eb7f6 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_70bb2272b82546eb8aa1d5330f4b87f0\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_70bb2272b82546eb8aa1d5330f4b87f0\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-uqxhyp49'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_70bb2272b82546eb8aa1d5330f4b87f0\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/13/73/f80b491ed8559326fab202a6d6333a3cd6e8be1e9d782bc6c0d03d476457/Fiona-1.8.10.tar.gz#sha256=ff562eb2f3960e21f8c7f050ddd7f47a763869ea14afc2234a40df72666c6a2c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Requirement already satisfied: jupyterlab-pygments in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.3)
# Requirement already satisfied: nest-asyncio in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (1.10)
# Requirement already satisfied: packaging in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (20.9)
# Requirement already satisfied: webencodings in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ffrei\appdata\local\programs\python\python39\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.0.0->keplergl) (2.4.7)
# Using legacy 'setup.py install' for keplergl, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for fiona, since package 'wheel' is not installed.
# Installing collected packages: click, munch, cligj, click-plugins, Shapely, pyproj, fiona, traittypes, geopandas, keplergl
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_773a1572b94b4186b56811e3db24e9b2\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_773a1572b94b4186b56811e3db24e9b2\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-enn3v5y4'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_773a1572b94b4186b56811e3db24e9b2\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9b/52/45e75507660ce0e86176d0f59b659560f687e2c7e9ebf82a10e7dcd2d3b7/Fiona-1.8.9.post2.tar.gz#sha256=210fb038b579fab38f35ddbdd31b9725f4d5099b3edfd4b87c983e5d47b79983 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_4acff95e2d944b969d8728a0dbd0ab23\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_4acff95e2d944b969d8728a0dbd0ab23\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ffrei\AppData\Local\Temp\pip-pip-egg-info-gpe1988t'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_4acff95e2d944b969d8728a0dbd0ab23\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages
). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_384a48540e244db99c62d12930b892cb\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_384a48540e244db99c62d12930b892cb\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\ffrei\AppData\Local\Temp\pip-record-fj_0tjap\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\ffrei\appdata\local\programs\python\python39\Include\fiona'
#          cwd: C:\Users\ffrei\AppData\Local\Temp\pip-install-c2wgfdo6\fiona_384a48540e244db99c62d12930b892cb\
#     Complete output (42 lines):
#     c:\users\ffrei\appdata\local\programs\python\python39\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     c:\users\ffrei\appdata\local\programs\python\python39\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     c:\users\ffrei\appdata\local\programs\python\python39\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\fiona
#     copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#     copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#     creating build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#     copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_384a48540e244db99c62d12930b892cb\\setup.py'"'"'; __file__='"'"'C:\\Users\\ffrei\\AppData\\Local\\Temp\\pip-install-c2wgfdo6\\fiona_384a48540e244db99c62d12930b892cb\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\ffrei\AppData\Local\Temp\pip-record-fj_0tjap\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\users\ffrei\appdata\local\programs\python\python39\Include\fiona' Check the logs for full command output.
# WARNING: You are using pip version 21.0.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\ffrei\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# Import libraries
import folium
import pandas as pd
import folium.plugins

# %%
# Import data
df = pd.read_csv('ufo.csv')

# %%
# Select data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78509 entries, 0 to 78508
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   78509 non-null  int64
#  1   datetime     78509 non-null  object
#  2   city         78509 non-null  object
#  3   state        72714 non-null  object
#  4   country      68947 non-null  object
#  5   shape        76599 non-null  object
#  6   duration     78509 non-null  float64
#  7   total_time   78509 non-null  object
#  8   comments     78495 non-null  object
#  9   date_posted  78509 non-null  object
#  10  latitude     78509 non-null  float64
#  11  longitude    78509 non-null  float64
#  12  year         78509 non-null  int64
#  13  distance     78509 non-null  float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 8.4+ MB

# %%
df2 = df[(df.year >= 2004) & (df.country >= 'us')]
df2['count'] = [i for i in range(len(df2))]
df2.head()
# Out:
# <ipython-input-24-e93ff0f35990>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['count'] = [i for i in range(len(df2))]
#    Unnamed: 0          datetime        city state country     shape  duration  \
# 0           0  10/10/1949 20:30  san marcos    tx      us  cylinder    2700.0
# 3           3  10/10/1956 21:00        edna    tx      us    circle      20.0
# 4           4  10/10/1960 20:00     kaneohe    hi      us     light     900.0
# 5           5  10/10/1961 19:00     bristol    tn      us    sphere     300.0
# 8           9  10/10/1966 21:00    live oak    fl      us      disk     120.0
#
#         total_time                                           comments  \
# 0       45 minutes  This event took place in early fall around 194...
# 3         1/2 hour  My older brother and twin sister were leaving ...
# 4       15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5        5 minutes  My father is now 89 my brother 52 the girl wit...
# 8  several minutes  Saucer zaps energy from powerline as my pregna...
#
#   date_posted   latitude   longitude  year     distance  count
# 0   4/27/2004  29.883056  -97.941111  2004  1242.667772      0
# 3   1/17/2004  28.978333  -96.645833  2004  1211.971352      1
# 4   1/22/2004  21.418056 -157.803611  2004  6960.923396      2
# 5   4/27/2007  36.595000  -82.188889  2007   427.334113      3
# 8   5/11/2005  30.294722  -82.984167  2005   749.440164      4

# %%
def base_mapa(default=[40.732029, -73.988129], zoom=11):
    
    mapa= folium.Map(location=default, zoom_start=zoom)
    
    return mapa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4f8b61b2bc15> in <module>
#       1 # Find the city
#       2
# ----> 3 base_map = base_mapa() # crea mapa
#       4
#       5 HM(data=df2[['latitude',
#
# NameError: name 'base_mapa' is not defined
